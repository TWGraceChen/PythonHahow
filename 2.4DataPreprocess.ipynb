# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from io import StringIO

# %% [markdown]
# ## Missing Data

# %%
csv_data = '''A,B,C,D,E
            5.0,2.0,3.0,,6
            1.0,6.0,,8.0,5
            0.0,11.0,12.0,4.0,5
            3.0,,3.0,5.0,
            5.0,1.0,4.0,2.0,4
           '''

# %%
df = pd.read_csv(StringIO(csv_data))

# %%
df
# Out:
#      A     B     C    D    E
# 0  5.0   2.0   3.0  NaN  6.0
# 1  1.0   6.0   NaN  8.0  5.0
# 2  0.0  11.0  12.0  4.0  5.0
# 3  3.0   NaN   3.0  5.0  NaN
# 4  5.0   1.0   4.0  2.0  4.0

# %%
df.dropna()
# Out:
#      A     B     C    D    E
# 2  0.0  11.0  12.0  4.0  5.0
# 4  5.0   1.0   4.0  2.0  4.0

# %%
df.dropna(how='all')
# Out:
#      A     B     C    D    E
# 0  5.0   2.0   3.0  NaN  6.0
# 1  1.0   6.0   NaN  8.0  5.0
# 2  0.0  11.0  12.0  4.0  5.0
# 3  3.0   NaN   3.0  5.0  NaN
# 4  5.0   1.0   4.0  2.0  4.0

# %%
# drop value if subset is na
df.dropna(subset=['C'])
# Out:
#      A     B     C    D    E
# 0  5.0   2.0   3.0  NaN  6.0
# 2  0.0  11.0  12.0  4.0  5.0
# 3  3.0   NaN   3.0  5.0  NaN
# 4  5.0   1.0   4.0  2.0  4.0

# %%
df.fillna(0)
# Out:
#      A     B     C    D    E
# 0  5.0   2.0   3.0  0.0  6.0
# 1  1.0   6.0   0.0  8.0  5.0
# 2  0.0  11.0  12.0  4.0  5.0
# 3  3.0   0.0   3.0  5.0  0.0
# 4  5.0   1.0   4.0  2.0  4.0

# %%
df['B'] = df['B'].fillna(df['B'].mean())
df
# Out:
#      A     B     C    D    E
# 0  5.0   2.0   3.0  NaN  6.0
# 1  1.0   6.0   NaN  8.0  5.0
# 2  0.0  11.0  12.0  4.0  5.0
# 3  3.0   5.0   3.0  5.0  NaN
# 4  5.0   1.0   4.0  2.0  4.0

# %%
df['C'] = df['C'].fillna(df['C'].mode())
df
# Out:
#      A     B     C    D    E
# 0  5.0   2.0   3.0  NaN  6.0
# 1  1.0   6.0   NaN  8.0  5.0
# 2  0.0  11.0  12.0  4.0  5.0
# 3  3.0   5.0   3.0  5.0  NaN
# 4  5.0   1.0   4.0  2.0  4.0

# %% [markdown]
# ## Categorical Data

# %%
df2 = pd.DataFrame(
    [['green', 'M', 10.1, 1],
    ['red', 'L', 13.5, 2],
    ['blue', 'XL', 15.3, 1]]
)
df2.columns = ['color', 'size', 'price', 'classlabel']
df2
# Out:
#    color size  price  classlabel
# 0  green    M   10.1           1
# 1    red    L   13.5           2
# 2   blue   XL   15.3           1

# %%
size_mapping = {
    'XL':3,
    'L':2,
    'M':1
}
df2['size'] = df2['size'].map(size_mapping)
df2
# Out:
#    color  size  price  classlabel
# 0  green     1   10.1           1
# 1    red     2   13.5           2
# 2   blue     3   15.3           1

# %%
# one-hot encoding
pd.get_dummies(df2['color'])
# Out:
#    blue  green  red
# 0     0      1    0
# 1     0      0    1
# 2     1      0    0

# %%
onehot_encoding = pd.get_dummies(df2['color'],prefix='color')

# %%
df2 = df2.drop('color',1)
df2
# Out:
# /tmp/ipykernel_10249/3532359213.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df2 = df2.drop('color',1)
#    size  price  classlabel
# 0     1   10.1           1
# 1     2   13.5           2
# 2     3   15.3           1

# %%
pd.concat([df2,onehot_encoding],axis=1)
# Out:
#    size  price  classlabel  color_blue  color_green  color_red
# 0     1   10.1           1           0            1          0
# 1     2   13.5           2           0            0          1
# 2     3   15.3           1           1            0          0

# %% [markdown]
# ## Feature Scaling

# %%
iris = datasets.load_iris()
x = pd.DataFrame(iris['data'],columns=iris['feature_names'])
y = pd.DataFrame(iris['target'],columns=['target_names'])
data = pd.concat([x,y],axis=1)
data.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target_names
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
data['sepal length (cm)'] = (data['sepal length (cm)'] - data['sepal length (cm)'].min()) / \
                            (data['sepal length (cm)'].max()-data['sepal length (cm)'].min())
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0           0.222222               3.5                1.4               0.2
# 1           0.166667               3.0                1.4               0.2
# 2           0.111111               3.2                1.3               0.2
# 3           0.083333               3.1                1.5               0.2
# 4           0.194444               3.6                1.4               0.2
#
#    target_names
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
data['sepal width (cm)'] = (data['sepal width (cm)'] - data['sepal width (cm)'].mean()) / \
                           (data['sepal width (cm)'].std())
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0           0.222222          1.015602                1.4               0.2
# 1           0.166667         -0.131539                1.4               0.2
# 2           0.111111          0.327318                1.3               0.2
# 3           0.083333          0.097889                1.5               0.2
# 4           0.194444          1.245030                1.4               0.2
#
#    target_names
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
