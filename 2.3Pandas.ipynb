# %%
from sklearn import datasets
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series

# %%
s1 = pd.Series([1,3,6,np.nan,44,1])
print(type(s1))
s1
# Out:
# <class 'pandas.core.series.Series'>
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    44.0
# 5     1.0
# dtype: float64

# %%
s2 = pd.Series([1,2,3],index=["a","b","c"])
print(type(s2))
s2
# Out:
# <class 'pandas.core.series.Series'>
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# ## DataFrame

# %%
df = pd.DataFrame(np.random.randn(6,4),columns=["a","b","c","d"])
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           a         b         c         d
# 0  1.525186 -0.664595  0.497822 -0.412492
# 1  0.374062 -1.036379  0.862249 -1.337414
# 2 -0.921349  1.674332 -1.280915  2.091188
# 3  1.943792 -0.074678 -0.908291  2.560752
# 4  0.044518  0.183122  2.982964 -0.651482
# 5 -1.121684  0.100430 -1.091394  0.111128

# %%
iris  = datasets.load_iris()
x = pd.DataFrame(iris["data"],columns=iris["feature_names"])
y = pd.DataFrame(iris["target"],columns=["target_names"])
data = pd.concat([x,y],axis=1)
data.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
#
#    target_names
# 0             0
# 1             0
# 2             0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target_names       150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
data.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)  target_names
# count        150.000000    150.000000
# mean           1.199333      1.000000
# std            0.762238      0.819232
# min            0.100000      0.000000
# 25%            0.300000      0.000000
# 50%            1.300000      1.000000
# 75%            1.800000      2.000000
# max            2.500000      2.000000

# %%
data.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target_names'],
#       dtype='object')

# %%
# sorting
data.sort_values(by='sepal length (cm)').head(5)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 13                4.3               3.0                1.1               0.1
# 42                4.4               3.2                1.3               0.2
# 38                4.4               3.0                1.3               0.2
# 8                 4.4               2.9                1.4               0.2
# 41                4.5               2.3                1.3               0.3
#
#     target_names
# 13             0
# 42             0
# 38             0
# 8              0
# 41             0

# %%
data['sepal length (cm)'].head(5)
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal length (cm), dtype: float64

# %%
data[['sepal length (cm)','sepal width (cm)']].head(5)
# Out:
#    sepal length (cm)  sepal width (cm)
# 0                5.1               3.5
# 1                4.9               3.0
# 2                4.7               3.2
# 3                4.6               3.1
# 4                5.0               3.6

# %%
data[5:10][['sepal length (cm)','sepal width (cm)']]
# Out:
#    sepal length (cm)  sepal width (cm)
# 5                5.4               3.9
# 6                4.6               3.4
# 7                5.0               3.4
# 8                4.4               2.9
# 9                4.9               3.1

# %%
data.loc[5:10,['sepal length (cm)','sepal width (cm)']]
# Out:
#     sepal length (cm)  sepal width (cm)
# 5                 5.4               3.9
# 6                 4.6               3.4
# 7                 5.0               3.4
# 8                 4.4               2.9
# 9                 4.9               3.1
# 10                5.4               3.7

# %%
# filter
data[data['sepal length (cm)'] > 7]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 102                7.1               3.0                5.9               2.1
# 105                7.6               3.0                6.6               2.1
# 107                7.3               2.9                6.3               1.8
# 109                7.2               3.6                6.1               2.5
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 122                7.7               2.8                6.7               2.0
# 125                7.2               3.2                6.0               1.8
# 129                7.2               3.0                5.8               1.6
# 130                7.4               2.8                6.1               1.9
# 131                7.9               3.8                6.4               2.0
# 135                7.7               3.0                6.1               2.3
#
#      target_names
# 102             2
# 105             2
# 107             2
# 109             2
# 117             2
# 118             2
# 122             2
# 125             2
# 129             2
# 130             2
# 131             2
# 135             2

# %%
# group by + aggregate
data.groupby(by="target_names").sum()
# Out:
#               sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target_names
# 0                         250.3             171.4               73.1
# 1                         296.8             138.5              213.0
# 2                         329.4             148.7              277.6
#
#               petal width (cm)
# target_names
# 0                         12.3
# 1                         66.3
# 2                        101.3

# %%
data.groupby(by="target_names").mean()
# Out:
#               sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target_names
# 0                         5.006             3.428              1.462
# 1                         5.936             2.770              4.260
# 2                         6.588             2.974              5.552
#
#               petal width (cm)
# target_names
# 0                        0.246
# 1                        1.326
# 2                        2.026
